# %% [markdown]
# # pandas complete tutorial for data science in 2026

# %% [markdown]
# ### import
#
# Before moving on to learn pandas first we need to install it and import it . if you install Anaconda distrubtion on your local machine or using Google colab then pandas will alreday be avaliable there,otherwise,you follow this installation process from pandas offical website

# %%
# importing libaries
import numpy as np
import pandas as pd

# %% [markdown]
# # 2. Loading Different data formats into a pandas data frame

# %% [markdown]
# ### Reading the CSV

# %%
# Import pandas library first
import pandas as pd

# Import Datasets
df = pd.read_csv("C:\\Users\\HP\\OneDrive\\Desktop\\PANDS\\dataset\\online_store_customer_data.csv")

# %%
df
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 0            1/1/2019          151200  Female  19.0         Single
# 1            1/1/2019          151201    Male  49.0         Single
# 2            1/1/2019          151202    Male  63.0        Married
# 3            1/1/2019          151203     NaN  18.0         Single
# 4            1/1/2019          151204    Male  27.0         Single
# ...               ...             ...     ...   ...            ...
# 2507         5/1/2021          153695  Female  57.0         Single
# 2508         5/1/2021          153696  Female  36.0        Married
# 2509         5/1/2021          153697    Male  22.0         Single
# 2510         5/1/2021          153698     NaN  44.0         Single
# 2511         5/1/2021          153699    Male  48.0         Single
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 0             Kansas     Basic     Unemployment          Other      1.0
# 1           Illinois     Basic    self-employed           Card      0.0
# 2         New Mexico     Basic          workers         PayPal      1.0
# 3           Virginia  Platinum          workers           Card      NaN
# 4        Connecticut     Basic    self-employed           Card      0.0
# ...              ...       ...              ...            ...      ...
# 2507  South Carolina  Platinum    self-employed           Card      0.0
# 2508          Hawaii    Silver    self-employed         PayPal      1.0
# 2509  South Carolina     Basic          workers         PayPal      1.0
# 2510        New York     Basic        Employees         PayPal      0.0
# 2511      California    Silver          workers         PayPal      1.0
#
#       Amount_spent
# 0          2051.36
# 1           544.04
# 2          1572.60
# 3          1199.79
# 4              NaN
# ...            ...
# 2507        150.10
# 2508        708.88
# 2509       2030.07
# 2510       1909.77
# 2511       1073.15
#
# [2512 rows x 11 columns]

# %%
df.head()
# Out:
#   Transaction_date  Transaction_ID  Gender   Age Marital_status  State_names  \
# 0         1/1/2019          151200  Female  19.0         Single       Kansas
# 1         1/1/2019          151201    Male  49.0         Single     Illinois
# 2         1/1/2019          151202    Male  63.0        Married   New Mexico
# 3         1/1/2019          151203     NaN  18.0         Single     Virginia
# 4         1/1/2019          151204    Male  27.0         Single  Connecticut
#
#     Segment Employees_status Payment_method  Referal  Amount_spent
# 0     Basic     Unemployment          Other      1.0       2051.36
# 1     Basic    self-employed           Card      0.0        544.04
# 2     Basic          workers         PayPal      1.0       1572.60
# 3  Platinum          workers           Card      NaN       1199.79
# 4     Basic    self-employed           Card      0.0           NaN

# %%
df.tail(7)
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 2505        4/30/2021          153693    Male  54.0        Married
# 2506        4/30/2021          153694    Male  34.0         Single
# 2507         5/1/2021          153695  Female  57.0         Single
# 2508         5/1/2021          153696  Female  36.0        Married
# 2509         5/1/2021          153697    Male  22.0         Single
# 2510         5/1/2021          153698     NaN  44.0         Single
# 2511         5/1/2021          153699    Male  48.0         Single
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 2505         Alabama     Basic        Employees           Card      0.0
# 2506         Florida   Missing        Employees          Other      1.0
# 2507  South Carolina  Platinum    self-employed           Card      0.0
# 2508          Hawaii    Silver    self-employed         PayPal      1.0
# 2509  South Carolina     Basic          workers         PayPal      1.0
# 2510        New York     Basic        Employees         PayPal      0.0
# 2511      California    Silver          workers         PayPal      1.0
#
#       Amount_spent
# 2505        266.61
# 2506        286.82
# 2507        150.10
# 2508        708.88
# 2509       2030.07
# 2510       1909.77
# 2511       1073.15

# %%
df.tail()
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 2507         5/1/2021          153695  Female  57.0         Single
# 2508         5/1/2021          153696  Female  36.0        Married
# 2509         5/1/2021          153697    Male  22.0         Single
# 2510         5/1/2021          153698     NaN  44.0         Single
# 2511         5/1/2021          153699    Male  48.0         Single
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 2507  South Carolina  Platinum    self-employed           Card      0.0
# 2508          Hawaii    Silver    self-employed         PayPal      1.0
# 2509  South Carolina     Basic          workers         PayPal      1.0
# 2510        New York     Basic        Employees         PayPal      0.0
# 2511      California    Silver          workers         PayPal      1.0
#
#       Amount_spent
# 2507        150.10
# 2508        708.88
# 2509       2030.07
# 2510       1909.77
# 2511       1073.15

# %%
df.shape
# Out:
# (2512, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2512 entries, 0 to 2511
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction_date  2512 non-null   object
#  1   Transaction_ID    2512 non-null   int64
#  2   Gender            2484 non-null   object
#  3   Age               2470 non-null   float64
#  4   Marital_status    2512 non-null   object
#  5   State_names       2512 non-null   object
#  6   Segment           2512 non-null   object
#  7   Employees_status  2486 non-null   object
#  8   Payment_method    2512 non-null   object
#  9   Referal           2356 non-null   float64
#  10  Amount_spent      2270 non-null   float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 216.0+ KB

# %%
df.size
# Out:
# 27632

# %%
import sys
sys.getsizeof(df)
# Out:
# 1065064

# %%
import sys 
my_float = 3.14159
sys.getsizeof(my_float)
# Out:
# 24

# %% [markdown]
# ### Read CSV file from URL

# %%
url1= "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
df_url = pd.read_csv(url1)
df_url
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
# using UCI Repository
# !pip install ucimlrepo
# Out:
# Collecting ucimlrepo
#   Downloading ucimlrepo-0.0.7-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: pandas>=1.0.0 in c:\users\hp\anaconda3\lib\site-packages (from ucimlrepo) (2.3.3)
# Requirement already satisfied: certifi>=2020.12.5 in c:\users\hp\anaconda3\lib\site-packages (from ucimlrepo) (2026.5.20)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\hp\anaconda3\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\anaconda3\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\anaconda3\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->ucimlrepo) (1.17.0)
# Downloading ucimlrepo-0.0.7-py3-none-any.whl (8.0 kB)
# Installing collected packages: ucimlrepo
# Successfully installed ucimlrepo-0.0.7

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
wine_quality = fetch_ucirepo(id=186) 
  
# data (as pandas dataframes) 
X = wine_quality.data.features 
y = wine_quality.data.targets 
  
# metadata 
print(wine_quality.metadata) 
  
# variable information 
print(wine_quality.variables)
# Out:
# {'uci_id': 186, 'name': 'Wine Quality', 'repository_url': 'https://archive.ics.uci.edu/dataset/186/wine+quality', 'data_url': 'https://archive.ics.uci.edu/static/public/186/data.csv', 'abstract': 'Two datasets are included, related to red and white vinho verde wine samples, from the north of Portugal. The goal is to model wine quality based on physicochemical tests (see [Cortez et al., 2009], http://www3.dsi.uminho.pt/pcortez/wine/).', 'area': 'Business', 'tasks': ['Classification', 'Regression'], 'characteristics': ['Multivariate'], 'num_instances': 4898, 'num_features': 11, 'feature_types': ['Real'], 'demographics': [], 'target_col': ['quality'], 'index_col': None, 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 2009, 'last_updated': 'Wed Nov 15 2023', 'dataset_doi': '10.24432/C56S3T', 'creators': ['Paulo Cortez', 'A. Cerdeira', 'F. Almeida', 'T. Matos', 'J. Reis'], 'intro_paper': {'ID': 252, 'type': 'NATIVE', 'title': 'Modeling wine preferences by data mining from physicochemical properties', 'authors': 'P. Cortez, A. Cerdeira, Fernando Almeida, Telmo Matos, J. Reis', 'venue': 'Decision Support Systems', 'year': 2009, 'journal': None, 'DOI': None, 'URL': 'https://www.semanticscholar.org/paper/Modeling-wine-preferences-by-data-mining-from-Cortez-Cerdeira/bf15a0ccc14ac1deb5cea570c870389c16be019c', 'sha': None, 'corpus': None, 'arxiv': None, 'mag': None, 'acl': None, 'pmid': None, 'pmcid': None}, 'additional_info': {'summary': 'The two datasets are related to red and white variants of the Portuguese "Vinho Verde" wine. For more details, consult: http://www.vinhoverde.pt/en/ or the reference [Cortez et al., 2009].  Due to privacy and logistic issues, only physicochemical (inputs) and sensory (the output) variables are available (e.g. there is no data about grape types, wine brand, wine selling price, etc.).\n\nThese datasets can be viewed as classification or regression tasks.  The classes are ordered and not balanced (e.g. there are many more normal wines than excellent or poor ones). Outlier detection algorithms could be used to detect the few excellent or poor wines. Also, we are not sure if all input variables are relevant. So it could be interesting to test feature selection methods.\n', 'purpose': None, 'funded_by': None, 'instances_represent': None, 'recommended_data_splits': None, 'sensitive_data': None, 'preprocessing_description': None, 'variable_info': 'For more information, read [Cortez et al., 2009].\r\nInput variables (based on physicochemical tests):\r\n   1 - fixed acidity\r\n   2 - volatile acidity\r\n   3 - citric acid\r\n   4 - residual sugar\r\n   5 - chlorides\r\n   6 - free sulfur dioxide\r\n   7 - total sulfur dioxide\r\n   8 - density\r\n   9 - pH\r\n   10 - sulphates\r\n   11 - alcohol\r\nOutput variable (based on sensory data): \r\n   12 - quality (score between 0 and 10)', 'citation': None}}
#                     name     role         type demographic  \
# 0          fixed_acidity  Feature   Continuous        None
# 1       volatile_acidity  Feature   Continuous        None
# 2            citric_acid  Feature   Continuous        None
# 3         residual_sugar  Feature   Continuous        None
# 4              chlorides  Feature   Continuous        None
# 5    free_sulfur_dioxide  Feature   Continuous        None
# 6   total_sulfur_dioxide  Feature   Continuous        None
# 7                density  Feature   Continuous        None
# 8                     pH  Feature   Continuous        None
# 9              sulphates  Feature   Continuous        None
# 10               alcohol  Feature   Continuous        None
# 11               quality   Target      Integer        None
# 12                 color    Other  Categorical        None
#
#                description units missing_values
# 0                     None  None             no
# 1                     None  None             no
# 2                     None  None             no
# 3                     None  None             no
# 4                     None  None             no
# 5                     None  None             no
# 6                     None  None             no
# 7                     None  None             no
# 8                     None  None             no
# 9                     None  None             no
# 10                    None  None             no
# 11  score between 0 and 10  None             no
# 12            red or white  None             no

# %% [markdown]
# ### Read text file

# %%
df_txt = pd.read_csv("C:\\Users\\HP\\OneDrive\\Desktop\\PANDS\\dataset\\demo_text.txt")
df_txt
# Out:
#      Unnamed: 0  5.1  3.5  1.4  0.2     Iris-setosa
# 0             0  4.9  3.0  1.4  0.2     Iris-setosa
# 1             1  4.7  3.2  1.3  0.2     Iris-setosa
# 2             2  4.6  3.1  1.5  0.2     Iris-setosa
# 3             3  5.0  3.6  1.4  0.2     Iris-setosa
# 4             4  5.4  3.9  1.7  0.4     Iris-setosa
# ..          ...  ...  ...  ...  ...             ...
# 144         144  6.7  3.0  5.2  2.3  Iris-virginica
# 145         145  6.3  2.5  5.0  1.9  Iris-virginica
# 146         146  6.5  3.0  5.2  2.0  Iris-virginica
# 147         147  6.2  3.4  5.4  2.3  Iris-virginica
# 148         148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 6 columns]

# %% [markdown]
# ### Read Excel file

# %%
import pandas as pd  # Import pandas library and assign it the alias 'pd'

df_excel = pd.read_excel(r"C:\Users\HP\OneDrive\Desktop\PANDS\dataset\excel_file.xlsx", sheet_name='Data')
df_excel
# Out:
#   Transaction_date  Transaction_ID  Gender  Age Marital_status   State_names  \
# 0        3/10/2019          151378  Female   25         Single       Wyoming
# 1         7/2/2019          151751  Female   42         Single      Delaware
# 2        6/14/2019          151689    Male   38        Married       Montana
# 3         8/5/2019          151849    Male   24        Married  Rhode Island
#
#     Segment Employees_status Payment_method  Referal  Amount_spent  \
# 0  Platinum     Unemployment           Card        1       2740.57
# 1     Basic     Unemployment           Card        0        977.80
# 2     Basic          workers         PayPal        1       2978.21
# 3     Basic          workers           Card        1       1157.79
#
#    Transaction_ID.1
# 0            151378
# 1            151751
# 2            151689
# 3            151849

# %% [markdown]
# ### write Excel file

# %%
# Save dataframe to excel
df_url.to_csv("excel_file.xlsx")

# %% [markdown]
# # Data Preprocessing
# Data preprocessing is the making raw data clean data . The is the most crucial part of data the
# science . In this section, we explore data first then we remove unwanted columns, remove duplicates,
# handle missing data

# %% [markdown]
# ### Data Exploring
# Retriveing rows from data frame

# %% [markdown]
# ### Display no of rows & columns

# %%
df.columns
# Out:
# Index(['Transaction_date', 'Transaction_ID', 'Gender', 'Age', 'Marital_status',
#        'State_names', 'Segment', 'Employees_status', 'Payment_method',
#        'Referal', 'Amount_spent'],
#       dtype='object')

# %%
# display age columns first 6 rows data
df['Age'].head(6)
# Out:
# 0    19.0
# 1    49.0
# 2    63.0
# 3    18.0
# 4    27.0
# 5    71.0
# Name: Age, dtype: float64

# %%
# display first 4 rows of age, transaction _data & gender
df[['Age','Transaction_date','Gender']].head(4)
# Out:
#     Age Transaction_date  Gender
# 0  19.0         1/1/2019  Female
# 1  49.0         1/1/2019    Male
# 2  63.0         1/1/2019    Male
# 3  18.0         1/1/2019     NaN

# %%
df[['Age','Transaction_date','Gender']].tail(10)
# Out:
#        Age Transaction_date  Gender
# 2502  16.0        4/29/2021    Male
# 2503  67.0        4/29/2021    Male
# 2504  34.0        4/30/2021    Male
# 2505  54.0        4/30/2021    Male
# 2506  34.0        4/30/2021    Male
# 2507  57.0         5/1/2021  Female
# 2508  36.0         5/1/2021  Female
# 2509  22.0         5/1/2021    Male
# 2510  44.0         5/1/2021     NaN
# 2511  48.0         5/1/2021    Male

# %% [markdown]
# ### Retrieving a Range of Rows

# %%
#for display 2nd to 6th rows
df[2:7]
# Out:
#   Transaction_date  Transaction_ID  Gender   Age Marital_status  State_names  \
# 2         1/1/2019          151202    Male  63.0        Married   New Mexico
# 3         1/1/2019          151203     NaN  18.0         Single     Virginia
# 4         1/1/2019          151204    Male  27.0         Single  Connecticut
# 5         1/3/2019          151205    Male  71.0         Single       Hawaii
# 6         1/3/2019          151206  Female  34.0        Married   New Mexico
#
#     Segment Employees_status Payment_method  Referal  Amount_spent
# 2     Basic          workers         PayPal      1.0       1572.60
# 3  Platinum          workers           Card      NaN       1199.79
# 4     Basic    self-employed           Card      0.0           NaN
# 5     Basic        Employees         PayPal      1.0       2922.66
# 6  Platinum        Employees         PayPal      1.0       1481.42

# %%
#for display starting to 10th
df[:11]
# Out:
#    Transaction_date  Transaction_ID  Gender   Age Marital_status  State_names  \
# 0          1/1/2019          151200  Female  19.0         Single       Kansas
# 1          1/1/2019          151201    Male  49.0         Single     Illinois
# 2          1/1/2019          151202    Male  63.0        Married   New Mexico
# 3          1/1/2019          151203     NaN  18.0         Single     Virginia
# 4          1/1/2019          151204    Male  27.0         Single  Connecticut
# 5          1/3/2019          151205    Male  71.0         Single       Hawaii
# 6          1/3/2019          151206  Female  34.0        Married   New Mexico
# 7          1/3/2019          151207    Male  37.0        Married  Connecticut
# 8          1/4/2019          151208    Male  75.0        Married      Florida
# 9          1/4/2019          151209  Female  41.0        Married      Vermont
# 10         1/4/2019          151210  Female  56.0        Married   California
#
#      Segment Employees_status Payment_method  Referal  Amount_spent
# 0      Basic     Unemployment          Other      1.0       2051.36
# 1      Basic    self-employed           Card      0.0        544.04
# 2      Basic          workers         PayPal      1.0       1572.60
# 3   Platinum          workers           Card      NaN       1199.79
# 4      Basic    self-employed           Card      0.0           NaN
# 5      Basic        Employees         PayPal      1.0       2922.66
# 6   Platinum        Employees         PayPal      1.0       1481.42
# 7      Basic          workers         PayPal      1.0       1149.55
# 8     Silver        Employees           Card      0.0       1046.20
# 9       Gold     Unemployment           Card      1.0       2730.60
# 10     Basic        Employees         PayPal      0.0       1712.82

# %%
#for display last two rows
df[-2:]
# Out:
#      Transaction_date  Transaction_ID Gender   Age Marital_status State_names  \
# 2510         5/1/2021          153698    NaN  44.0         Single    New York
# 2511         5/1/2021          153699   Male  48.0         Single  California
#
#      Segment Employees_status Payment_method  Referal  Amount_spent
# 2510   Basic        Employees         PayPal      0.0       1909.77
# 2511  Silver          workers         PayPal      1.0       1073.15

# %% [markdown]
# # 3.2 Data cleaning
# After the explore our datasets may need to clean them for better analysis.Data coming
# in from multiple source so it's possible to have an error in some value.This is where data cleaning becomes extremly important

# %% [markdown]
# ## Delete Columns name

# %%
# DROP UNWANTED COLUMNS
df.drop(['Transaction_ID'], axis=1, inplace=True)

# %%
df
# Out:
#      Transaction_date  Gender   Age Marital_status     State_names   Segment  \
# 0            1/1/2019  Female  19.0         Single          Kansas     Basic
# 1            1/1/2019    Male  49.0         Single        Illinois     Basic
# 2            1/1/2019    Male  63.0        Married      New Mexico     Basic
# 3            1/1/2019     NaN  18.0         Single        Virginia  Platinum
# 4            1/1/2019    Male  27.0         Single     Connecticut     Basic
# ...               ...     ...   ...            ...             ...       ...
# 2507         5/1/2021  Female  57.0         Single  South Carolina  Platinum
# 2508         5/1/2021  Female  36.0        Married          Hawaii    Silver
# 2509         5/1/2021    Male  22.0         Single  South Carolina     Basic
# 2510         5/1/2021     NaN  44.0         Single        New York     Basic
# 2511         5/1/2021    Male  48.0         Single      California    Silver
#
#      Employees_status Payment_method  Referal  Amount_spent
# 0        Unemployment          Other      1.0       2051.36
# 1       self-employed           Card      0.0        544.04
# 2             workers         PayPal      1.0       1572.60
# 3             workers           Card      NaN       1199.79
# 4       self-employed           Card      0.0           NaN
# ...               ...            ...      ...           ...
# 2507    self-employed           Card      0.0        150.10
# 2508    self-employed         PayPal      1.0        708.88
# 2509          workers         PayPal      1.0       2030.07
# 2510        Employees         PayPal      0.0       1909.77
# 2511          workers         PayPal      1.0       1073.15
#
# [2512 rows x 10 columns]

# %% [markdown]
# ## Change Columns name

# %%
# create new df_col dataframe from df.copy(short cut)
df_col = df.copy()
df_col
# Out:
#      Transaction_date  Gender   Age Marital_status     State_names   Segment  \
# 0            1/1/2019  Female  19.0         Single          Kansas     Basic
# 1            1/1/2019    Male  49.0         Single        Illinois     Basic
# 2            1/1/2019    Male  63.0        Married      New Mexico     Basic
# 3            1/1/2019     NaN  18.0         Single        Virginia  Platinum
# 4            1/1/2019    Male  27.0         Single     Connecticut     Basic
# ...               ...     ...   ...            ...             ...       ...
# 2507         5/1/2021  Female  57.0         Single  South Carolina  Platinum
# 2508         5/1/2021  Female  36.0        Married          Hawaii    Silver
# 2509         5/1/2021    Male  22.0         Single  South Carolina     Basic
# 2510         5/1/2021     NaN  44.0         Single        New York     Basic
# 2511         5/1/2021    Male  48.0         Single      California    Silver
#
#      Employees_status Payment_method  Referal  Amount_spent
# 0        Unemployment          Other      1.0       2051.36
# 1       self-employed           Card      0.0        544.04
# 2             workers         PayPal      1.0       1572.60
# 3             workers           Card      NaN       1199.79
# 4       self-employed           Card      0.0           NaN
# ...               ...            ...      ...           ...
# 2507    self-employed           Card      0.0        150.10
# 2508    self-employed         PayPal      1.0        708.88
# 2509          workers         PayPal      1.0       2030.07
# 2510        Employees         PayPal      0.0       1909.77
# 2511          workers         PayPal      1.0       1073.15
#
# [2512 rows x 10 columns]

# %%
# rename columns name 
df_col.rename(columns={"Transaction_date": "Date", "Gender": "Sex"},inplace=True)
df_col.head(3)
# Out:
#        Date     Sex   Age Marital_status State_names Segment Employees_status  \
# 0  1/1/2019  Female  19.0         Single      Kansas   Basic     Unemployment
# 1  1/1/2019    Male  49.0         Single    Illinois   Basic    self-employed
# 2  1/1/2019    Male  63.0        Married  New Mexico   Basic          workers
#
#   Payment_method  Referal  Amount_spent
# 0          Other      1.0       2051.36
# 1           Card      0.0        544.04
# 2         PayPal      1.0       1572.60

# %% [markdown]
# ## rename columns name

# %%
# create new df_col dataframe from df.copy()
df_col = df.copy()
df_col
# Out:
#      Transaction_date  Gender   Age Marital_status     State_names   Segment  \
# 0            1/1/2019  Female  19.0         Single          Kansas     Basic
# 1            1/1/2019    Male  49.0         Single        Illinois     Basic
# 2            1/1/2019    Male  63.0        Married      New Mexico     Basic
# 3            1/1/2019     NaN  18.0         Single        Virginia  Platinum
# 4            1/1/2019    Male  27.0         Single     Connecticut     Basic
# ...               ...     ...   ...            ...             ...       ...
# 2507         5/1/2021  Female  57.0         Single  South Carolina  Platinum
# 2508         5/1/2021  Female  36.0        Married          Hawaii    Silver
# 2509         5/1/2021    Male  22.0         Single  South Carolina     Basic
# 2510         5/1/2021     NaN  44.0         Single        New York     Basic
# 2511         5/1/2021    Male  48.0         Single      California    Silver
#
#      Employees_status Payment_method  Referal  Amount_spent
# 0        Unemployment          Other      1.0       2051.36
# 1       self-employed           Card      0.0        544.04
# 2             workers         PayPal      1.0       1572.60
# 3             workers           Card      NaN       1199.79
# 4       self-employed           Card      0.0           NaN
# ...               ...            ...      ...           ...
# 2507    self-employed           Card      0.0        150.10
# 2508    self-employed         PayPal      1.0        708.88
# 2509          workers         PayPal      1.0       2030.07
# 2510        Employees         PayPal      0.0       1909.77
# 2511          workers         PayPal      1.0       1073.15
#
# [2512 rows x 10 columns]

# %% [markdown]
# ## Adding new column to a Dataframe

# %%
# add a new adjust column
df_col['Test'] = df_col['Amount_spent'] * 10

# %%
df_col.head(3)
# Out:
#   Transaction_date  Gender   Age Marital_status State_names Segment  \
# 0         1/1/2019  Female  19.0         Single      Kansas   Basic
# 1         1/1/2019    Male  49.0         Single    Illinois   Basic
# 2         1/1/2019    Male  63.0        Married  New Mexico   Basic
#
#   Employees_status Payment_method  Referal  Amount_spent     Test
# 0     Unemployment          Other      1.0       2051.36  20513.6
# 1    self-employed           Card      0.0        544.04   5440.4
# 2          workers         PayPal      1.0       1572.60  15726.0

# %% [markdown]
# ## Datatypes change

# %%
import pandas as pd

# First, create or load the DataFrame (example with sample data)
# Option 1: Create sample DataFrame
df_col = pd.DataFrame({
    'sex': ['Female', 'Male', 'Female', 'Male', 'Female']
})

# Option 2: Or load from a file (uncomment if needed)
# df_col = pd.read_csv('your_file.csv')

# Now fix the original logic - use proper column assignment instead of loc
df_col.loc[df_col['sex'] == "Female", 'sex'] = "woman"  # Specify column name in loc
df_col.loc[df_col['sex'] == "Male", 'sex'] = "Man"      # Specify column name in loc

print(df_col)
# Out:
#      sex
# 0  woman
# 1    Man
# 2  woman
# 3    Man
# 4  woman

# %%
df_col.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2512 entries, 0 to 2511
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction_date  2512 non-null   object
#  1   Gender            2484 non-null   object
#  2   Age               2470 non-null   float64
#  3   Marital_status    2512 non-null   object
#  4   State_names       2512 non-null   object
#  5   Segment           2512 non-null   object
#  6   Employees_status  2486 non-null   object
#  7   Payment_method    2512 non-null   object
#  8   Referal           2356 non-null   float64
#  9   Amount_spent      2270 non-null   float64
#  10  Test              2270 non-null   float64
# dtypes: float64(4), object(7)
# memory usage: 216.0+ KB

# %%
# First, check what columns are available in your DataFrame
print("Available columns:", df_col.columns.tolist())

# Option 1: If the column exists but has a different name, replace 'Date' with the correct name
# For example, if it's actually called 'date' or 'DATE':
# df_col['date'] = df_col['date'].astype('datetime64[ns]')

# Option 2: If there are extra spaces, strip them first
df_col.columns = df_col.columns.str.strip()

# Option 3: Use this safer approach that handles the column if it exists
if 'Date' in df_col.columns:
    # Change object type to datetime64 format
    df_col['Date'] = df_col['Date'].astype('datetime64[ns]')
else:
    print("Column 'Date' not found. Available columns are:", df_col.columns.tolist())

# Apply the same safety check for 'Referal' column
if 'Referal' in df_col.columns:
    df_col['Referal'] = df_col['Referal'].astype('float32')
else:
    print("Column 'Referal' not found. Available columns are:", df_col.columns.tolist())
# Out:
# Available columns: ['Transaction_date', 'Gender', 'Age', 'Marital_status', 'State_names', 'Segment', 'Employees_status', 'Payment_method', 'Referal', 'Amount_spent', 'Test']
# Column 'Date' not found. Available columns are: ['Transaction_date', 'Gender', 'Age', 'Marital_status', 'State_names', 'Segment', 'Employees_status', 'Payment_method', 'Referal', 'Amount_spent', 'Test']

# %%
import pandas as pd



# Option 1: Create from a dictionary
df_col = pd.DataFrame({
    'column1': [1, 2, 3, 4],
    'column2': ['A', 'B', 'C', 'D'],
    'column3': [10.5, 20.3, 30.1, 40.7]
})

df_col.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   column1  4 non-null      int64
#  1   column2  4 non-null      object
#  2   column3  4 non-null      float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 228.0+ bytes

# %% [markdown]
# ## Remove duplicate

# %%
df_col.duplicated().sum()
# Out:
# np.int64(12)

# %%
# First, you need to create or load your DataFrame
# Example of creating a DataFrame:
import pandas as pd

# Create a sample DataFrame (replace this with your actual data source)
df_Col = pd.DataFrame({
    'column1': [1, 2, 2, 3, 4],
    'column2': ['A', 'B', 'B', 'C', 'D']
})

df_Col.duplicated().head()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# dtype: bool

# %%
import pandas as pd

# Create or load your DataFrame first (example with sample data)
df = pd.DataFrame({
    'A': [1, 2, 2, 3, 4],
    'B': [5, 6, 6, 7, 8],
    'C': [9, 10, 10, 11, 12]
})

duplicate_value = df.duplicated(keep='first')
duplicate_value
df.loc[duplicate_value, :]  # Fixed: changed hyphen to underscore
# Out:
#    A  B   C
# 2  2  6  10

# %%
# dropping all duplicate values
df.drop_duplicates(keep = 'first', inplace = True)
df.drop_duplicates()  # Removed the invalid 'cd' characters that were causing the syntax error
# Out:
#    A  B   C
# 0  1  5   9
# 1  2  6  10
# 3  3  7  11
# 4  4  8  12

# %% [markdown]
# ### Handling Missing values
# Handling missing values in the columns task in the data pre-processing part.
# for many reason most of the time we will encounter missing values.without dealing with this we can't do the proper
# model buliding

# %% [markdown]
# ### Display missing values info

# %%
import pandas as pd


df = pd.DataFrame({
    'A': [1, 2, None, 4],
    'B': [None, 2, 3, 4],
    'C': [1, None, None, 4]
})

# Now your original code will work
df.isna().sum().sort_values(ascending=False)
# Out:
# C    2
# A    1
# B    1
# dtype: int64

# %%
df
# Out:
#      A    B    C
# 0  1.0  NaN  1.0
# 1  2.0  2.0  NaN
# 2  NaN  3.0  NaN
# 3  4.0  4.0  4.0

# %% [markdown]
# ## Delete Nan rows

# %%
# df copy to df-copy
df_new = df.copy()

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      float64
#  1   B       3 non-null      float64
#  2   C       2 non-null      float64
# dtypes: float64(3)
# memory usage: 228.0 bytes

# %%
# First, check what columns actually exist in the DataFrame
print("Available columns:", df_new.columns.tolist())

# Option 1: Use errors='ignore' to avoid the error if column doesn't exist
df_new.drop(columns=['Amount_spent'], inplace=True, errors='ignore')

df_new
# Out:
# Available columns: ['A', 'B', 'C']
#      A    B    C
# 0  1.0  NaN  1.0
# 1  2.0  2.0  NaN
# 2  NaN  3.0  NaN
# 3  4.0  4.0  4.0

# %%
df_new.isna().sum().sort_values(ascending=False)
# Out:
# C    2
# A    1
# B    1
# dtype: int64

# %% [markdown]
# ## Impute missing values
# Sometime if we delete entires columns that will be not the appropiate approach.Delete columns can affect our model buliding because we
# will lose our main features.For imputing we have many approches so here are some of the most popular technique

# %%
df
# Out:
#      A    B    C
# 0  1.0  NaN  1.0
# 1  2.0  2.0  NaN
# 2  NaN  3.0  NaN
# 3  4.0  4.0  4.0

# %%
# First, check what columns exist in your DataFrame
print("Available columns:", df.columns.tolist())

# Check if 'Gender' column exists before trying to fill NaN values
if 'Gender' in df.columns:
    df['Gender'].fillna('RNS', inplace=True)
else:
    print("Column 'Gender' not found. Please check the correct column name.")
    
df
# Out:
# Available columns: ['A', 'B', 'C']
# Column 'Gender' not found. Please check the correct column name.
#      A    B    C
# 0  1.0  NaN  1.0
# 1  2.0  2.0  NaN
# 2  NaN  3.0  NaN
# 3  4.0  4.0  4.0

# %% [markdown]
# ## METHOD 2 : IMPUTE MEAN , MEADIAN & MODE

# %%
# Impute Mean in Amount_spent columns
mean_amount_spent = df['Amount_spent'].mean()
df['Amount_spent'].fillna(mean_amount_spent, inplace=True)
df
mean_amount_spent
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_1780\1963031892.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Amount_spent'].fillna(mean_amount_spent, inplace=True)
# np.float64(1418.4225770925111)

# %%
#Impute Median in Age column
median_age = df['Age'].median()
df['Age'].fillna(median_age, inplace=True)
median_age
df
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_1780\1747953670.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(median_age, inplace=True)
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 0            1/1/2019          151200  Female  19.0         Single
# 1            1/1/2019          151201    Male  49.0         Single
# 2            1/1/2019          151202    Male  63.0        Married
# 3            1/1/2019          151203     NaN  18.0         Single
# 4            1/1/2019          151204    Male  27.0         Single
# ...               ...             ...     ...   ...            ...
# 2507         5/1/2021          153695  Female  57.0         Single
# 2508         5/1/2021          153696  Female  36.0        Married
# 2509         5/1/2021          153697    Male  22.0         Single
# 2510         5/1/2021          153698     NaN  44.0         Single
# 2511         5/1/2021          153699    Male  48.0         Single
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 0             Kansas     Basic     Unemployment          Other      1.0
# 1           Illinois     Basic    self-employed           Card      0.0
# 2         New Mexico     Basic          workers         PayPal      1.0
# 3           Virginia  Platinum          workers           Card      NaN
# 4        Connecticut     Basic    self-employed           Card      0.0
# ...              ...       ...              ...            ...      ...
# 2507  South Carolina  Platinum    self-employed           Card      0.0
# 2508          Hawaii    Silver    self-employed         PayPal      1.0
# 2509  South Carolina     Basic          workers         PayPal      1.0
# 2510        New York     Basic        Employees         PayPal      0.0
# 2511      California    Silver          workers         PayPal      1.0
#
#       Amount_spent
# 0      2051.360000
# 1       544.040000
# 2      1572.600000
# 3      1199.790000
# 4      1418.422577
# ...            ...
# 2507    150.100000
# 2508    708.880000
# 2509   2030.070000
# 2510   1909.770000
# 2511   1073.150000
#
# [2512 rows x 11 columns]

# %%
 #Impute Mode in Employees_status column
mode_emp = df['Employees_status'].mode().iloc[0]
df['Employees_status'].fillna(mode_emp, inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_1780\4127432755.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Employees_status'].fillna(mode_emp, inplace=True)

# %%
mean_amount_spent
# Out:
# np.float64(1418.4225770925111)

# %%
mode_emp
# Out:
# 'Employees'

# %%
median_age
# Out:
# 47.0

# %% [markdown]
# ## Method 3 -
# Imputing forward fill or backfill by ffill and bfill. In ffill missing value impute from the value of the above row and for bfill it's taken from the below rows value.

# %%
df
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 0            1/1/2019          151200  Female  19.0         Single
# 1            1/1/2019          151201    Male  49.0         Single
# 2            1/1/2019          151202    Male  63.0        Married
# 3            1/1/2019          151203     NaN  18.0         Single
# 4            1/1/2019          151204    Male  27.0         Single
# ...               ...             ...     ...   ...            ...
# 2507         5/1/2021          153695  Female  57.0         Single
# 2508         5/1/2021          153696  Female  36.0        Married
# 2509         5/1/2021          153697    Male  22.0         Single
# 2510         5/1/2021          153698     NaN  44.0         Single
# 2511         5/1/2021          153699    Male  48.0         Single
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 0             Kansas     Basic     Unemployment          Other      1.0
# 1           Illinois     Basic    self-employed           Card      0.0
# 2         New Mexico     Basic          workers         PayPal      1.0
# 3           Virginia  Platinum          workers           Card      1.0
# 4        Connecticut     Basic    self-employed           Card      0.0
# ...              ...       ...              ...            ...      ...
# 2507  South Carolina  Platinum    self-employed           Card      0.0
# 2508          Hawaii    Silver    self-employed         PayPal      1.0
# 2509  South Carolina     Basic          workers         PayPal      1.0
# 2510        New York     Basic        Employees         PayPal      0.0
# 2511      California    Silver          workers         PayPal      1.0
#
#       Amount_spent
# 0      2051.360000
# 1       544.040000
# 2      1572.600000
# 3      1199.790000
# 4      1418.422577
# ...            ...
# 2507    150.100000
# 2508    708.880000
# 2509   2030.070000
# 2510   1909.770000
# 2511   1073.150000
#
# [2512 rows x 11 columns]

# %%
df['Referal'].fillna(method='ffill', inplace=True)
df
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_1780\1967400654.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Referal'].fillna(method='ffill', inplace=True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_1780\1967400654.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Referal'].fillna(method='ffill', inplace=True)
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 0            1/1/2019          151200  Female  19.0         Single
# 1            1/1/2019          151201    Male  49.0         Single
# 2            1/1/2019          151202    Male  63.0        Married
# 3            1/1/2019          151203     NaN  18.0         Single
# 4            1/1/2019          151204    Male  27.0         Single
# ...               ...             ...     ...   ...            ...
# 2507         5/1/2021          153695  Female  57.0         Single
# 2508         5/1/2021          153696  Female  36.0        Married
# 2509         5/1/2021          153697    Male  22.0         Single
# 2510         5/1/2021          153698     NaN  44.0         Single
# 2511         5/1/2021          153699    Male  48.0         Single
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 0             Kansas     Basic     Unemployment          Other      1.0
# 1           Illinois     Basic    self-employed           Card      0.0
# 2         New Mexico     Basic          workers         PayPal      1.0
# 3           Virginia  Platinum          workers           Card      1.0
# 4        Connecticut     Basic    self-employed           Card      0.0
# ...              ...       ...              ...            ...      ...
# 2507  South Carolina  Platinum    self-employed           Card      0.0
# 2508          Hawaii    Silver    self-employed         PayPal      1.0
# 2509  South Carolina     Basic          workers         PayPal      1.0
# 2510        New York     Basic        Employees         PayPal      0.0
# 2511      California    Silver          workers         PayPal      1.0
#
#       Amount_spent
# 0      2051.360000
# 1       544.040000
# 2      1572.600000
# 3      1199.790000
# 4      1418.422577
# ...            ...
# 2507    150.100000
# 2508    708.880000
# 2509   2030.070000
# 2510   1909.770000
# 2511   1073.150000
#
# [2512 rows x 11 columns]

# %%
df.isna().sum().sum()
# Out:
# np.int64(28)

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# Gender              28
# Transaction_date     0
# Transaction_ID       0
# Age                  0
# Marital_status       0
# State_names          0
# Segment              0
# Employees_status     0
# Payment_method       0
# Referal              0
# Amount_spent         0
# dtype: int64

# %% [markdown]
# ## Memory Mangement
# When we work on large datasets, There we get one big issue is a memory problem. We need too large resources for dealing with this. But there are some methods in pandas to deal with this. Here are some methods or strategies to deal with this problem with help of pandas.

# %% [markdown]
# ### Change datatypes

# %%
df_memory = df.copy()

# %%
import numpy as np  # Import NumPy library with alias 'np'

memory_usage = df_memory.memory_usage(deep=True)
memory_usage_in_mbs = round(np.sum(memory_usage / 1024 ** 2), 3)
print(f" Total memory taking df_memory dataframe is : {memory_usage_in_mbs:.2f} MB ")
# Out:
#  Total memory taking df_memory dataframe is : 1.02 MB

# %% [markdown]
# ### Change the object to category datatype

# %%
# Object datatype to category convert
df_memory[df_memory.select_dtypes(['object']).columns] = df_memory.select_dtypes(['object']).apply(lambda x: x.astype('category'))

# %%
df_memory[df_memory.select_dtypes(['float64']).columns] = df_memory.select_dtypes(['float64']).apply(lambda x: x.astype('float32'))

# %%
# convert object to category
df_memory.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2512 entries, 0 to 2511
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction_date  2512 non-null   category
#  1   Transaction_ID    2512 non-null   int64
#  2   Gender            2484 non-null   category
#  3   Age               2512 non-null   float32
#  4   Marital_status    2512 non-null   category
#  5   State_names       2512 non-null   category
#  6   Segment           2512 non-null   category
#  7   Employees_status  2512 non-null   category
#  8   Payment_method    2512 non-null   category
#  9   Referal           2512 non-null   float32
#  10  Amount_spent      2512 non-null   float32
# dtypes: category(7), float32(3), int64(1)
# memory usage: 153.3 KB

# %% [markdown]
#  ### Change int64 or float64 to int 32, 16, or 8
#  By default, pandas store numeric values to int64 or float64. Which takes more memory. If we have to store small numbers then we can change to 64 to 32, 16, and so on. For example, our Referal columns have only 0 and 1 values so for that we don't need to store at float64. so now we change it to float16.

# %%
# Change Referal column datatypes
df_memory['Referal'] = df_memory['Referal'].astype('float16')

# %%
# convert object to category
df_memory.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2512 entries, 0 to 2511
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction_date  2512 non-null   category
#  1   Transaction_ID    2512 non-null   int64
#  2   Gender            2484 non-null   category
#  3   Age               2512 non-null   float32
#  4   Marital_status    2512 non-null   category
#  5   State_names       2512 non-null   category
#  6   Segment           2512 non-null   category
#  7   Employees_status  2512 non-null   category
#  8   Payment_method    2512 non-null   category
#  9   Referal           2512 non-null   float32
#  10  Amount_spent      2512 non-null   float32
# dtypes: category(7), float32(3), int64(1)
# memory usage: 153.3 KB

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ### Calculating Basic statistical measurement

# %%
df.describe().T
# Out:
#                  count           mean         std        min          25%  \
# Transaction_ID  2512.0  152443.931131  724.580482  151200.00  151815.7500
# Age             2512.0      46.643710   18.033600      15.00      32.0000
# Referal         2512.0       0.655255    0.475380       0.00       0.0000
# Amount_spent    2512.0    1418.422577  835.101648       2.09     734.8625
#
#                           50%          75%        max
# Transaction_ID  152443.500000  153071.2500  153699.00
# Age                 47.000000      62.0000      78.00
# Referal              1.000000       1.0000       1.00
# Amount_spent      1418.422577    1955.9975    2999.98

# %%
df.describe(include=object).T
# Out:
#                  count unique        top  freq
# Transaction_date  2512    810  8/29/2020    12
# Gender            2484      2     Female  1356
# Marital_status    2512      2    Married  1473
# State_names       2512     50   Illinois    67
# Segment           2512      5      Basic  1136
# Employees_status  2512      4  Employees   972
# Payment_method    2512      3     PayPal  1168

# %% [markdown]
# ##### We can calculate the mean, median, mode, maximum values, minimum values of individual columns we simply use these functions.

# %%
# Calculate Mean
mean = df['Age'].mean()
print(f" Mean of Age : {mean}")
# Out:
#  Mean of Age : 46.6437101910828

# %%
median = df['Age'].median()
print(f" Median of Age : {median}")
# Out:
#  Median of Age : 47.0

# %%
mode = df['Age'].mode().iloc[0]
print(f" Mode of Age : {mode}")
# Out:
#  Mode of Age : 47.0

# %%
# Calculate Minimum values
minimum = df['Age'].min()
print(f" Menimum of Age : {minimum}")
# Out:
#  Menimum of Age : 15.0

# %%
# Calculate Maximum values
maximum = df.Age.max()
print(f" Maximum of Age : {maximum}")
# Out:
#  Maximum of Age : 78.0

# %% [markdown]
# ## Basic built in function for data analysis

# %%
# for display how many unique values are there in State_names column
df['State_names'].nunique()
# Out:
# 50

# %%
# for display uniqe values of State_names column
df['State_names'].unique()
# Out:
# array(['Kansas', 'Illinois', 'New Mexico', 'Virginia', 'Connecticut',
#        'Hawaii', 'Florida', 'Vermont', 'California', 'Colorado', 'Iowa',
#        'South Carolina', 'New York', 'Maine', 'Maryland', 'Missouri',
#        'North Dakota', 'Ohio', 'Nebraska', 'Montana', 'Indiana',
#        'Wisconsin', 'Alabama', 'Arkansas', 'Pennsylvania',
#        'New Hampshire', 'Washington', 'Texas', 'Kentucky',
#        'Massachusetts', 'Wyoming', 'Louisiana', 'North Carolina',
#        'Rhode Island', 'West Virginia', 'Tennessee', 'Oregon', 'Alaska',
#        'Oklahoma', 'Nevada', 'New Jersey', 'Michigan', 'Utah', 'Arizona',
#        'South Dakota', 'Georgia', 'Idaho', 'Mississippi', 'Minnesota',
#        'Delaware'], dtype=object)

# %%
df['State_names'].value_counts().T
# Out:
# State_names
# Illinois          67
# Georgia           64
# Massachusetts     63
# Maine             62
# Kentucky          59
# Minnesota         59
# Missouri          57
# Arizona           56
# Delaware          56
# Arkansas          55
# Nevada            55
# New York          55
# California        55
# New Mexico        55
# Vermont           54
# West Virginia     54
# New Jersey        53
# Oregon            53
# Florida           53
# Connecticut       52
# Washington        52
# Pennsylvania      52
# Colorado          52
# South Dakota      52
# Michigan          52
# Iowa              51
# Rhode Island      51
# Louisiana         49
# Texas             49
# Montana           48
# North Carolina    46
# Virginia          46
# Hawaii            46
# Wisconsin         45
# Idaho             45
# Maryland          45
# South Carolina    45
# Wyoming           44
# Mississippi       44
# Oklahoma          44
# Utah              43
# New Hampshire     43
# Indiana           43
# Ohio              43
# Alabama           42
# Alaska            41
# Nebraska          41
# North Dakota      41
# Kansas            41
# Tennessee         39
# Name: count, dtype: int64

# %% [markdown]
# #### If we want to show with the percentage of occurrence rather number than we use normalize=True argument in value_counts() function

# %%
# Calculate percentage of each category
df['State_names'].value_counts(normalize=True)
# Out:
# State_names
# Illinois          0.026672
# Georgia           0.025478
# Massachusetts     0.025080
# Maine             0.024682
# Kentucky          0.023487
# Minnesota         0.023487
# Missouri          0.022691
# Arizona           0.022293
# Delaware          0.022293
# Arkansas          0.021895
# Nevada            0.021895
# New York          0.021895
# California        0.021895
# New Mexico        0.021895
# Vermont           0.021497
# West Virginia     0.021497
# New Jersey        0.021099
# Oregon            0.021099
# Florida           0.021099
# Connecticut       0.020701
# Washington        0.020701
# Pennsylvania      0.020701
# Colorado          0.020701
# South Dakota      0.020701
# Michigan          0.020701
# Iowa              0.020303
# Rhode Island      0.020303
# Louisiana         0.019506
# Texas             0.019506
# Montana           0.019108
# North Carolina    0.018312
# Virginia          0.018312
# Hawaii            0.018312
# Wisconsin         0.017914
# Idaho             0.017914
# Maryland          0.017914
# South Carolina    0.017914
# Wyoming           0.017516
# Mississippi       0.017516
# Oklahoma          0.017516
# Utah              0.017118
# New Hampshire     0.017118
# Indiana           0.017118
# Ohio              0.017118
# Alabama           0.016720
# Alaska            0.016322
# Nebraska          0.016322
# North Dakota      0.016322
# Kansas            0.016322
# Tennessee         0.015525
# Name: proportion, dtype: float64

# %%
df['State_names'].value_counts().sort_values(ascending = False).head(20)
# Out:
# State_names
# Illinois         67
# Georgia          64
# Massachusetts    63
# Maine            62
# Kentucky         59
# Minnesota        59
# Missouri         57
# Arizona          56
# Delaware         56
# New York         55
# California       55
# New Mexico       55
# Nevada           55
# Arkansas         55
# West Virginia    54
# Vermont          54
# New Jersey       53
# Oregon           53
# Florida          53
# Connecticut      52
# Name: count, dtype: int64

# %%
# Sort Values by State_names
df.sort_values(by=['State_names']).head(3)
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 617         7/21/2019          151805    Male  43.0        Married
# 1856        9/15/2020          153044  Female  18.0        Married
# 2443         4/9/2021          153631    Male  60.0        Married
#
#      State_names   Segment Employees_status Payment_method  Referal  \
# 617      Alabama    Silver        Employees         PayPal      1.0
# 1856     Alabama    Silver          workers         PayPal      0.0
# 2443     Alabama  Platinum        Employees         PayPal      1.0
#
#       Amount_spent
# 617      87.880000
# 1856   2091.730000
# 2443   1418.422577

# %%
# Sort Values Amount_spent with ascending order
df.sort_values(by=['Amount_spent']).head(5)
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 2468        4/18/2021          153656  Female  73.0        Married
# 568          7/4/2019          151756    Male  46.0         Single
# 2401        3/25/2021          153589  Female  60.0         Single
# 962        11/13/2019          152150  Female  56.0        Married
# 860        10/10/2019          152048    Male  26.0         Single
#
#          State_names Segment Employees_status Payment_method  Referal  \
# 2468        Michigan    Gold        Employees         PayPal      1.0
# 568   South Carolina    Gold          workers         PayPal      0.0
# 2401        Maryland  Silver        Employees         PayPal      1.0
# 962           Nevada   Basic          workers          Other      1.0
# 860         Maryland  Silver     Unemployment         PayPal      1.0
#
#       Amount_spent
# 2468          2.09
# 568           2.16
# 2401          2.84
# 962           5.31
# 860           5.55

# %%
# Sort Values Amount_spent with descending order
df.sort_values(by=['Amount_spent'], ascending=False).head(3)
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 17           1/7/2019          151217  Female  77.0        Married
# 485          6/7/2019          151673    Male  65.0        Married
# 2279        2/15/2021          153467  Female  78.0         Single
#
#      State_names   Segment Employees_status Payment_method  Referal  \
# 17    New Mexico  Platinum          workers           Card      0.0
# 485      Arizona      Gold    self-employed         PayPal      1.0
# 2279     Arizona    Silver        Employees         PayPal      1.0
#
#       Amount_spent
# 17         2999.98
# 485        2998.62
# 2279       2997.21

# %% [markdown]
# #### Alternatively, We can use nlargest() and nsmallest() functions for displaying largest and smallest values with desired numbers. for example, If we want to display 4 largest Amount_spent rows then we use this:

# %%
# nlargest
df.nlargest(2, 'Amount_spent').head()
# Out:
#     Transaction_date  Transaction_ID  Gender   Age Marital_status State_names  \
# 17          1/7/2019          151217  Female  77.0        Married  New Mexico
# 485         6/7/2019          151673    Male  65.0        Married     Arizona
#
#       Segment Employees_status Payment_method  Referal  Amount_spent
# 17   Platinum          workers           Card      0.0       2999.98
# 485      Gold    self-employed         PayPal      1.0       2998.62

# %%
# nsmallest
df.nsmallest(3, 'Age').head()
# Out:
#    Transaction_date  Transaction_ID Gender   Age Marital_status  \
# 33        1/14/2019          151233   Male  15.0        Married
# 54        1/23/2019          151254   Male  15.0        Married
# 62        1/26/2019          151262   Male  15.0        Married
#
#        State_names Segment Employees_status Payment_method  Referal  \
# 33        Missouri    Gold    self-employed           Card      1.0
# 54        Illinois   Basic        Employees           Card      1.0
# 62  South Carolina   Basic    self-employed          Other      1.0
#
#     Amount_spent
# 33        628.93
# 54       2690.18
# 62        790.10

# %% [markdown]
# ### Conditional query on data

# %%
# filtering - Only show Paypal users
condition = df['Payment_method'] == 'PayPal'
df[condition].head()
# Out:
#    Transaction_date  Transaction_ID  Gender   Age Marital_status  State_names  \
# 2          1/1/2019          151202    Male  63.0        Married   New Mexico
# 5          1/3/2019          151205    Male  71.0         Single       Hawaii
# 6          1/3/2019          151206  Female  34.0        Married   New Mexico
# 7          1/3/2019          151207    Male  37.0        Married  Connecticut
# 10         1/4/2019          151210  Female  56.0        Married   California
#
#      Segment Employees_status Payment_method  Referal  Amount_spent
# 2      Basic          workers         PayPal      1.0       1572.60
# 5      Basic        Employees         PayPal      1.0       2922.66
# 6   Platinum        Employees         PayPal      1.0       1481.42
# 7      Basic          workers         PayPal      1.0       1149.55
# 10     Basic        Employees         PayPal      0.0       1712.82

# %%
# filtering - Only show Paypal users
condition = df['Marital_status'] == 'Married'
df[condition].head()
# Out:
#   Transaction_date  Transaction_ID  Gender   Age Marital_status  State_names  \
# 2         1/1/2019          151202    Male  63.0        Married   New Mexico
# 6         1/3/2019          151206  Female  34.0        Married   New Mexico
# 7         1/3/2019          151207    Male  37.0        Married  Connecticut
# 8         1/4/2019          151208    Male  75.0        Married      Florida
# 9         1/4/2019          151209  Female  41.0        Married      Vermont
#
#     Segment Employees_status Payment_method  Referal  Amount_spent
# 2     Basic          workers         PayPal      1.0       1572.60
# 6  Platinum        Employees         PayPal      1.0       1481.42
# 7     Basic          workers         PayPal      1.0       1149.55
# 8    Silver        Employees           Card      0.0       1046.20
# 9      Gold     Unemployment           Card      1.0       2730.60

# %% [markdown]
#  #### We can apply multiple conditional queries like before. For example, if we want to display all Married female people who lived in New York then we use the following:

# %%
# first create 3 condition
female_person = df['Gender'] == 'Female'
married_person = df['Marital_status'] == 'Married'
loc_newyork = df['State_names'] == 'New York'

# we passing condition on our dataframe
df[female_person & married_person & loc_newyork].head()
# Out:
#     Transaction_date  Transaction_ID  Gender   Age Marital_status State_names  \
# 164         3/1/2019          151352  Female  64.0        Married    New York
# 180         3/7/2019          151368  Female  20.0        Married    New York
# 254        3/31/2019          151442  Female  78.0        Married    New York
# 282         4/8/2019          151470  Female  32.0        Married    New York
# 827        9/30/2019          152015  Female  77.0        Married    New York
#
#       Segment Employees_status Payment_method  Referal  Amount_spent
# 164     Basic        Employees         PayPal      1.0   1581.770000
# 180     Basic          workers         PayPal      1.0   2694.200000
# 254   Missing        Employees         PayPal      1.0   2959.540000
# 282      Gold     Unemployment          Other      1.0    522.240000
# 827  Platinum          workers           Card      1.0   1418.422577

# %% [markdown]
# ###  Summarizing or grouping data

# %% [markdown]
# #### Grouping by one column:
# For example, if we want to find maximum values of Age and Amount_spent by Gender then we can use this:

# %%
df[['Age', 'Amount_spent']].groupby(df['Gender']).max()
# Out:
#          Age  Amount_spent
# Gender
# Female  78.0       2999.98
# Male    78.0       2998.62

# %%
# Group by one columns
state_gender_res = df[['Age','Gender','Amount_spent']].groupby(['Gender']).agg(['count', 'mean', 'max'])
state_gender_res
# Out:
#          Age                  Amount_spent
#        count       mean   max        count         mean      max
# Gender
# Female  1356  46.867257  78.0         1356  1427.944121  2999.98
# Male    1128  46.481383  78.0         1128  1408.675018  2998.62

# %% [markdown]
# ### Grouping by multiple columns:
# To find total count, maximum and minimum values of Amount_spent by State_names, Gender, and Payment_method then we can pass these columns names under groupby() function and add .agg() with count, mean, max argument.

# %%
#Group By multiple columns
state_gender_res = df[['State_names','Gender','Payment_method','Amount_spent']].groupby([ 'State_names','Gender', 'Payment_method']).agg(['count', 'min', 'max'])
state_gender_res.head(12)
# Out:
#                                   Amount_spent
#                                          count      min      max
# State_names Gender Payment_method
# Alabama     Female Card                      8   413.11  2749.37
#                    Other                     6   851.25  2789.52
#                    PayPal                    6    77.90  2520.85
#             Male   Card                      6   221.17  2735.65
#                    Other                     4   459.47  1691.62
#                    PayPal                   11    87.88  2876.36
# Alaska      Female Card                      6   141.50  1988.38
#                    Other                     8   489.16  2970.00
#                    PayPal                   10   462.96  2615.89
#             Male   Card                      1  2497.31  2497.31
#                    Other                     8   588.88  2977.82
#                    PayPal                    8    91.32  1834.95

# %% [markdown]
# ## Cross Tabulation (Crosstab

# %% [markdown]
# ##### For creating a simple crosstab between Maritatal_status and Payment_method columns we just use `crosstab()` with both column names.

# %%
pd.crosstab(df.Payment_method, df.Gender)
# Out:
# Gender          Female  Male
# Payment_method
# Card               429   310
# Other              313   276
# PayPal             614   542

# %%
#We can include subtotals by margins parameter:
pd.crosstab(df.Marital_status, df.Payment_method, margins=True, margins_name="Total")
# Out:
# Payment_method  Card  Other  PayPal  Total
# Marital_status
# Married          441    362     670   1473
# Single           308    233     498   1039
# Total            749    595    1168   2512

# %%
#If We want a display with percentage than normalize=True parameter help
pd.crosstab(df.Marital_status, df.Payment_method, normalize=True, margins=True, margins_name="Total")
# Out:
# Payment_method      Card     Other    PayPal     Total
# Marital_status
# Married         0.175557  0.144108  0.266720  0.586385
# Single          0.122611  0.092755  0.198248  0.413615
# Total           0.298169  0.236863  0.464968  1.000000

# %% [markdown]
# ##### In this crosstab features, we can pass multiple columns names for grouping and analyzing data. For instance, If we want to see how the Payment_method and Employees_status are distributed by Marital_status then we will pass these columns' names in crosstab() function and it will show below.

# %%
pd.crosstab(df.Marital_status, [df.Payment_method, df.Employees_status])
# Out:
# Payment_method        Card                                        Other  \
# Employees_status Employees Unemployment self-employed workers Employees
# Marital_status
# Married                186           38            81     136       128
# Single                 118           37            57      96        96
#
# Payment_method                                         PayPal               \
# Employees_status Unemployment self-employed workers Employees Unemployment
# Marital_status
# Married                    41            79     114       266           67
# Single                     17            44      76       178           55
#
# Payment_method
# Employees_status self-employed workers
# Marital_status
# Married                    120     217
# Single                     106     159

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ##### Visualization is the key to data analysis. The most popular python package for visualization are matplotlib and seaborn but sometimes pandas will be handy for you. Pandas also provide some visualization plots easily. For the basic analysis part, it will be easy to use. For this section, we are exploring some different types of plots using pandas. Here are the plots.

# %% [markdown]
# ## Line plot

# %%
dict_line = {
    'year': [2016, 2017, 2018, 2019, 2020, 2021],
    'price': [200, 250, 260, 220, 280, 300]
}
df_line = pd.DataFrame(dict_line)
df_line
# Out:
#    year  price
# 0  2016    200
# 1  2017    250
# 2  2018    260
# 3  2019    220
# 4  2020    280
# 5  2021    300

# %%
# use plot() method on the dataframe
df_line.plot('price', 'year');

# %% [markdown]
# ##  Bar plot
# A bar plot is also known as a bar chart shows quantitative or qualitative values for different category items. In a bar plot data are represented in the form of bars. Bars length or height are used to represent the quantitative value for each item. Bar plot can be plotted horizontally or vertically. For creating these plots look below.

# %%
df['Employees_status'].value_counts().plot(kind='bar');

# %%
df['Employees_status'].value_counts().plot(kind='barh');

# %% [markdown]
# ## Pie plot
# A pie plot is also known as a pie chart. A pie plot is a circular graph that represents the total value with its components. The area of a circle represents the total value and the different sectors of the circle represent the different parts. In this plot, the data are expressed as percentages. Each component is expressed as a percentage of the total value.

# %%
df['Segment'].value_counts().plot(kind='pie');

# %% [markdown]
# ##  Box Plot
# A box plot is also known as a box and whisker plot. This plot is used to show the distribution of a variable based on its quartiles. Box plot displays the five-number summary of a set of data. The five-number summary is the minimum, first quartile, median, third quartile, and maximum. It will also be popular to identify outliers.

# %%
df.plot(y=['Amount_spent',], kind='box');

# %%
import numpy as np

# %% [markdown]
# ## Histogram
# A histogram shows the frequency and distribution of quantitative measurement across grouped values for data items. It is commonly used in statistics to show how many of a certain type of variable occurs within a specific range or bucket. Below we will plot a histogram for looking Age distribution.

# %%
df.plot(
    y='Age',
    kind='hist',
    bins=20
);

# %% [markdown]
# ## KDE plot
# A kernel density estimate (KDE) plot is a method for visualizing the distribution of observations in a dataset, analogous to a histogram. KDE represents the data using a continuous probability density curve in one or more dimensions.

# %%
df.plot(
    y='Age',
    xlim=(0, 100),
    kind='kde'
);

# %% [markdown]
# ## Scatterplot
# A scatterplot is used to observe and show relationships between two quantitative variables for different category items. Each member of the dataset gets plotted as a point whose x-y coordinates relate to its values for the two variables. Below we will plot a scatterplot to display relationships between Age and Amount_spent columns.

# %%
df.plot(
    x='Age',
    y='Amount_spent',
    kind='scatter'
);

# %% [markdown]
# ## Reference
# 1. Pandas user guide
# 2. Pandas 1.x Cookbook
# 3. The Data Wrangling Workshop
# 4. Python for Data Analysis
# 5. Data Analysis with Python: Zero to Pandas - Jovian YouTube Channel
# 6. Best practices with pandas - Data School YouTube Channel
# 7. Pandas Tutorials - Corey Schafer YouTube Channel
# 8. Pandas Crosstab Explained
